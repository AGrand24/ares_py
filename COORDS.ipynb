# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import shapely
import plotly.graph_objects as go
import plotly.express as px

from ares_py.coords import process_line_distance, pt_to_ls
from ares_py.electrodes import ld2sec
from ares_py.class_project import Project

from pathlib import Path
from ares_py.coords import gpkg_rec_ls, gpkg_coord_pt, csv_topo, plot_coords_3d

# %% [markdown]
# 1. Run model **ert_proc_coord_processing_v2*
#     * select desired input linestring
#     * model interpolates pts along geometry and samples dtm from dtm.tif in qgis project folder
#     * model exports data to **C:\tmp\crd_proc_tmp.gpkg**
# 2. Select project and crd mode and run processing:
#     * crd -output spatial gpkg - **ert_pt**
#     * plan - output spatial gpkg - **ert_plan_pt**

# %%
prj = Project("budmerice")

gpkg_rec_ls(prj)
gdf = gpkg_coord_pt(prj=prj, mode="crd")
csv_topo(prj)
fig = plot_coords_3d(gdf)
# Out:
# c:\Users\adamg\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyogrio\raw.py:198: UserWarning:
#
# Measured (M) geometry types are not supported. Original type 'Measured 3D Point' is converted to 'Point Z'
# Exported - projects\budmerice\99_qgs\budmerice_spatial.gpkg - ert_pt
#          el_space  ld_hor     ld
# ID_line
# 1             2.0   78.80   79.0
# 2             2.0  254.62  255.0
# 3             2.0   81.88   82.0
# 4             2.0  256.68  258.0
